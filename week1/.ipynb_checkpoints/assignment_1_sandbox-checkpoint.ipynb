# %% [markdown]
# # Assignment 1
# \- Si Nguyen Mai, May 12, 2018 -

# %%
# for reading data
import pandas as pd
import numpy as np

# %%
song_dataset = pd.read_json('MasterSongList.json')
print('Raw data size: ', song_dataset.shape)
song_dataset.head()
# Out:
# Raw data size:  (36733, 16)
#                                     _id                  album  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}  Gangnam Style (강남스타일)
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}                 Native
# 2  {'$oid': '52fdfb420b9398049f3d3ea5'}      Party Rock Anthem
# 3  {'$oid': '52fdfb410b9398049f3d1eac'}              Gentleman
# 4  {'$oid': '52fdfb400b9398049f3d0b19'}           On The Floor
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2           LMFAO  [5, 0.709932, 0.231455, 130.03, 0.121740999999...
# 3             PSY  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  Jennifer Lopez  [3, 0.741757, 0.07277399999999999, 129.985, 0....
#
#                                         context  decades       genres  \
# 0                                    [work out]       []        [pop]
# 1                                   [energetic]   [2012]        [pop]
# 2  [energetic, energetic, energetic, energetic]       []           []
# 3    [party, party, party, party, party, party]  [2010s]      [dance]
# 4                                [party, party]  [2000s]  [reggaeton]
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
#
#                              moods                   name new_context  \
# 0        [energetic, motivational]  Gangnam Style (강남스타일)    work out
# 1                          [happy]         Counting Stars   energetic
# 2      [happy, celebratory, rowdy]      Party Rock Anthem   housework
# 3  [happy, energetic, celebratory]              Gentleman   energetic
# 4                      [energetic]           On The Floor    work out
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189

# %%
song_dataset['genres']
# Out:
# 0                                       [pop]
# 1                                       [pop]
# 2                                          []
# 3                                     [dance]
# 4                                 [reggaeton]
# 5                                          []
# 6                                 [r&b: soul]
# 7                                       [pop]
# 8                                          []
# 9                                       [pop]
# 10                                    [latin]
# 11                                         []
# 12                                      [pop]
# 13                                         []
# 14                                [reggaeton]
# 15                                      [pop]
# 16                                      [pop]
# 17                                      [pop]
# 18                                      [pop]
# 19                                         []
# 20                                    [dance]
# 21                                         []
# 22                                         []
# 23                                      [pop]
# 24                                      [pop]
# 25                                     [rock]
# 26                                      [pop]
# 27                                      [pop]
# 28                                [reggaeton]
# 29                                      [pop]
#                          ...
# 36703                             [r&b: soul]
# 36704                             [classical]
# 36705                           [film scores]
# 36706                          [reggae & ska]
# 36707                             [classical]
# 36708                             [bluegrass]
# 36709                             [bluegrass]
# 36710                   [international/world]
# 36711                             [classical]
# 36712                    [blues & blues rock]
# 36713                                  [jazz]
# 36714                                  [jazz]
# 36715                                      []
# 36716                                   [r&b]
# 36717                                 [latin]
# 36718                            [children's]
# 36719                                      []
# 36720    [rap: underground & alternative rap]
# 36721               [dance: disco & nu disco]
# 36722                                  [jazz]
# 36723                                   [rap]
# 36724                                      []
# 36725                                  [rock]
# 36726                     [indie: indie rock]
# 36727                                  [folk]
# 36728                             [classical]
# 36729                             [classical]
# 36730                                  [rock]
# 36731                                 [dance]
# 36732                                  [rock]
# Name: genres, Length: 36733, dtype: object

# %%
def consolidateGenres (genre):
    if (len(genre) > 0):
        gen = genre[0]
        return gen.split(':')[0]
    else:
        return "NA"
    
song_dataset.loc[:, 'genres']= song_dataset['genres'].apply(consolidateGenres)
song_dataset['genres']
# Out:
# 0                        pop
# 1                        pop
# 2                         NA
# 3                      dance
# 4                  reggaeton
# 5                         NA
# 6                        r&b
# 7                        pop
# 8                         NA
# 9                        pop
# 10                     latin
# 11                        NA
# 12                       pop
# 13                        NA
# 14                 reggaeton
# 15                       pop
# 16                       pop
# 17                       pop
# 18                       pop
# 19                        NA
# 20                     dance
# 21                        NA
# 22                        NA
# 23                       pop
# 24                       pop
# 25                      rock
# 26                       pop
# 27                       pop
# 28                 reggaeton
# 29                       pop
#                 ...
# 36703                    r&b
# 36704              classical
# 36705            film scores
# 36706           reggae & ska
# 36707              classical
# 36708              bluegrass
# 36709              bluegrass
# 36710    international/world
# 36711              classical
# 36712     blues & blues rock
# 36713                   jazz
# 36714                   jazz
# 36715                     NA
# 36716                    r&b
# 36717                  latin
# 36718             children's
# 36719                     NA
# 36720                    rap
# 36721                  dance
# 36722                   jazz
# 36723                    rap
# 36724                     NA
# 36725                   rock
# 36726                  indie
# 36727                   folk
# 36728              classical
# 36729              classical
# 36730                   rock
# 36731                  dance
# 36732                   rock
# Name: genres, Length: 36733, dtype: object

# %%
song_dataset.head()
# Out:
#                                     _id                  album  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}  Gangnam Style (강남스타일)
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}                 Native
# 2  {'$oid': '52fdfb420b9398049f3d3ea5'}      Party Rock Anthem
# 3  {'$oid': '52fdfb410b9398049f3d1eac'}              Gentleman
# 4  {'$oid': '52fdfb400b9398049f3d0b19'}           On The Floor
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2           LMFAO  [5, 0.709932, 0.231455, 130.03, 0.121740999999...
# 3             PSY  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  Jennifer Lopez  [3, 0.741757, 0.07277399999999999, 129.985, 0....
#
#                                         context  decades     genres  \
# 0                                    [work out]       []        pop
# 1                                   [energetic]   [2012]        pop
# 2  [energetic, energetic, energetic, energetic]       []         NA
# 3    [party, party, party, party, party, party]  [2010s]      dance
# 4                                [party, party]  [2000s]  reggaeton
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
#
#                              moods                   name new_context  \
# 0        [energetic, motivational]  Gangnam Style (강남스타일)    work out
# 1                          [happy]         Counting Stars   energetic
# 2      [happy, celebratory, rowdy]      Party Rock Anthem   housework
# 3  [happy, energetic, celebratory]              Gentleman   energetic
# 4                      [energetic]           On The Floor    work out
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189

# %%
rock_pop_idx = (song_dataset['genres'] == 'rock') | (song_dataset['genres'] == 'pop')
rock_pop_dataset = song_dataset.loc[rock_pop_idx].copy()
rock_pop_dataset.reset_index(drop = True, inplace = True)
print(rock_pop_dataset.shape)
rock_pop_dataset.head()
# Out:
# (8386, 16)
#                                     _id                              album  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}              Gangnam Style (강남스타일)
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}                             Native
# 2  {'$oid': '52fdfb440b9398049f3d7a7d'}                      Call Me Maybe
# 3  {'$oid': '52fdfb400b9398049f3d0dc7'}           What Makes You Beautiful
# 4  {'$oid': '52fdfb410b9398049f3d1908'}  Teenage Dream (Parental Advisory)
#
#              artist                                     audio_features  \
# 0               PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1       OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2  Carly Rae Jepsen  [7, 0.585564, 0.10829699999999999, 120.014, 0....
# 3     One Direction  [4, 0.81403, 0.079196, 124.991, 0.07244, 0.005...
# 4        Katy Perry  [8, 0.8695539999999999, 0.107945, 124.065, 0.0...
#
#                                              context  decades genres  \
# 0                                         [work out]       []    pop
# 1                                        [energetic]   [2012]    pop
# 2                                         [work out]       []    pop
# 3  [studying / working, studying / working, study...  [2010s]    pop
# 4                              [party, party, party]       []    pop
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [i, threw, a, wish, in, the, well, don, t, ask...
# 3  [don, t, know, what, for, you, re, turning, he...
# 4  [do, you, ever, feel, like, a, plastic, bag, d...
#
#                          moods                      name new_context  \
# 0    [energetic, motivational]     Gangnam Style (강남스타일)    work out
# 1                      [happy]            Counting Stars   energetic
# 2    [energetic, motivational]             Call Me Maybe    work out
# 3         [happy, celebratory]  What Makes You Beautiful   housework
# 4  [happy, celebratory, campy]                  Firework       party
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/064/604/149/...       35484.0
# 3  http://images.musicnet.com/albums/064/019/497/...       20475.0
# 4  http://images.musicnet.com/albums/044/189/817/...       50229.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2                              [working out: cardio]  fWNaR-rxAic   743689468
# 3  [energy boost, pleasing a crowd, housework, wo...  QJO3ROT-A4E   697513708
# 4  [house party, girls night out, dance party: fu...  QGJuMBdaqIw   643034892

# %%
def audioFeatureFrame (features_col, features_names):
    featureList = [features for features in features_col]
    frame = pd.DataFrame(featureList, columns = features_names)
    return frame

# %%
audioFeatures_names = ['key', 'energy', 'liveliness', 'tempo', 'speechiness', 'acousticness', 'instrumentalness', 
                  'time_signature', 'duration', 'loudness', 'valence', 'danceability', 'mode', 
                  'time_signature_confidence', 'tempo_confidence', 'key_confidence', 'mode_confidence']

# %% [markdown]
# ### Big dataset of rock and pop songs (6435 rock songs & 1889 pop songs), drop all NAs

# %%
audioFeatures = audioFeatureFrame(rock_pop_dataset.loc[:, 'audio_features'], audioFeatures_names)
audioFeatures.head()
# Out:
#     key    energy  liveliness    tempo  speechiness  acousticness  \
# 0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2   7.0  0.585564    0.108297  120.014     0.038924      0.011707
# 3   4.0  0.814030    0.079196  124.991     0.072440      0.005355
# 4   8.0  0.869554    0.107945  124.065     0.051083      0.132712
#
#    instrumentalness  time_signature  duration   loudness  valence  \
# 0          0.000001             0.0       4.0  218.30667   -3.890
# 1          0.012727             1.0       4.0  235.06086   -7.687
# 2          0.000005             1.0       4.0  193.57333   -6.583
# 3          0.000000             1.0       4.0  198.25333   -1.985
# 4          0.000000             1.0       4.0  227.97333   -3.739
#
#    danceability      mode  time_signature_confidence  tempo_confidence  \
# 0      0.752186  0.726920                      0.552             0.541
# 1      0.351282  0.691817                      0.737             0.634
# 2      0.622176  0.781822                      0.970             0.861
# 3      0.838512  0.700860                      0.429             0.375
# 4      0.639499  0.636239                      0.239             0.416
#
#    key_confidence  mode_confidence
# 0           1.000              1.0
# 1           0.796              1.0
# 2           0.792              1.0
# 3           0.740              1.0
# 4           0.669              1.0

# %%
audioFeatures_genres = pd.concat([audioFeatures, rock_pop_dataset.loc[:,'genres']], axis = 1)

# %%
audioFeatures_genres.dropna(axis = 0, how = 'any', inplace = True)
audioFeatures_genres.reset_index(drop = True, inplace = True)

# %%
rock_songs = audioFeatures_genres.loc[audioFeatures_genres['genres'] == 'rock'].copy()
rock_songs.reset_index(drop = True, inplace = True)
len(rock_songs)
# Out:
# 6435

# %%
pop_songs = audioFeatures_genres.loc[audioFeatures_genres['genres'] == 'pop'].copy()
pop_songs.reset_index(drop = True, inplace = True)
len(pop_songs)
# Out:
# 689

# %%
cleaned_audioFeatures = audioFeatures_genres.drop('genres', axis = 1).copy()
cleaned_audioFeatures.head()
# Out:
#     key    energy  liveliness    tempo  speechiness  acousticness  \
# 0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2   7.0  0.585564    0.108297  120.014     0.038924      0.011707
# 3   4.0  0.814030    0.079196  124.991     0.072440      0.005355
# 4   8.0  0.869554    0.107945  124.065     0.051083      0.132712
#
#    instrumentalness  time_signature  duration   loudness  valence  \
# 0          0.000001             0.0       4.0  218.30667   -3.890
# 1          0.012727             1.0       4.0  235.06086   -7.687
# 2          0.000005             1.0       4.0  193.57333   -6.583
# 3          0.000000             1.0       4.0  198.25333   -1.985
# 4          0.000000             1.0       4.0  227.97333   -3.739
#
#    danceability      mode  time_signature_confidence  tempo_confidence  \
# 0      0.752186  0.726920                      0.552             0.541
# 1      0.351282  0.691817                      0.737             0.634
# 2      0.622176  0.781822                      0.970             0.861
# 3      0.838512  0.700860                      0.429             0.375
# 4      0.639499  0.636239                      0.239             0.416
#
#    key_confidence  mode_confidence
# 0           1.000              1.0
# 1           0.796              1.0
# 2           0.792              1.0
# 3           0.740              1.0
# 4           0.669              1.0

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = MinMaxScaler()
scaled_audioFeatures = scaler.fit_transform(cleaned_audioFeatures)
scaled_audioFeatures
# Out:
# array([[ 1.        ,  0.91368442,  0.06924079, ...,  0.541     ,
#          1.        ,  1.        ],
#        [ 0.54545455,  0.74644373,  0.10614349, ...,  0.634     ,
#          0.796     ,  1.        ],
#        [ 0.63636364,  0.58611133,  0.09427591, ...,  0.861     ,
#          0.792     ,  1.        ],
#        ...,
#        [ 0.63636364,  0.94943532,  0.23326445, ...,  0.663     ,
#          0.048     ,  0.632     ],
#        [ 0.90909091,  0.62310372,  0.18987418, ...,  0.656     ,
#          0.52      ,  0.986     ],
#        [ 0.45454545,  0.5238366 ,  0.09517886, ...,  0.502     ,
#          0.895     ,  1.        ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split, cross_validate

# %%
from nltk import ConfusionMatrix
from sklearn.metrics import classification_report

# %%
k = 3
knn = KNeighborsClassifier(n_neighbors = k)

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_audioFeatures, audioFeatures_genres['genres'], 
                                                   shuffle = True, test_size = 0.3, random_state = 777)

# %%
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)
predictions
# Out:
# array(['rock', 'rock', 'rock', ..., 'pop', 'rock', 'rock'], dtype=object)

# %%
confus_mat = ConfusionMatrix(list(y_test), list(predictions))
classifi_report = classification_report(y_test, predictions)

print(confus_mat)
print('\n\n')
print(classifi_report)
# Out:
#      |         r |
#      |    p    o |
#      |    o    c |
#      |    p    k |
# -----+-----------+
#  pop |  <42> 177 |
# rock |   59<1860>|
# -----+-----------+
# (row = reference; col = test)
#
#
#
#
#              precision    recall  f1-score   support
#
#         pop       0.42      0.19      0.26       219
#        rock       0.91      0.97      0.94      1919
#
# avg / total       0.86      0.89      0.87      2138

# %%
from sklearn.metrics import precision_score, recall_score, make_scorer
custom_scorer = {'accuracy' : 'accuracy', 
                 'precision' : make_scorer(precision_score, average = 'micro'), 
                 'recall' : make_scorer(recall_score, average = 'micro')}

# %%
scores = cross_validate(knn, scaled_audioFeatures, audioFeatures_genres['genres'], 
                        scoring = custom_scorer, cv = 10, return_train_score=False)
scores
# Out:
# {'fit_time': array([ 0.03583717,  0.03524685,  0.03752422,  0.0319283 ,  0.03580713,
#          0.03456068,  0.03436732,  0.02864695,  0.03422618,  0.0382359 ]),
#  'score_time': array([ 0.37231946,  0.35394883,  0.35554647,  0.34725571,  0.38040805,
#          0.33496785,  0.33862209,  0.3534224 ,  0.35765171,  0.34564638]),
#  'test_accuracy': array([ 0.86676017,  0.86956522,  0.88218794,  0.87938289,  0.88639551,
#          0.88202247,  0.90308989,  0.89325843,  0.89747191,  0.90154712]),
#  'test_precision': array([ 0.86676017,  0.86956522,  0.88218794,  0.87938289,  0.88639551,
#          0.88202247,  0.90308989,  0.89325843,  0.89747191,  0.90154712]),
#  'test_recall': array([ 0.86676017,  0.86956522,  0.88218794,  0.87938289,  0.88639551,
#          0.88202247,  0.90308989,  0.89325843,  0.89747191,  0.90154712])}

# %%
print(np.mean(scores['test_accuracy']))
print(np.mean(scores['test_precision']))
print(np.mean(scores['test_recall']))
# Out:
# 0.886168153847
# 0.886168153847
# 0.886168153847

# %% [markdown]
# ### Balanced dataset of rock and pop songs (2000 rock songs & 1889 pop songs), drop all NAs

# %%
subset_rock_songs = audioFeatures_genres.sample(n=2000, axis = 0, random_state = 999)
subset_rock_songs.reset_index(drop = True, inplace = True)
# 7              0.476            1.000   rock
# 8              0.286            0.919   rock
# 9              0.385            0.886   rock
# 10             0.009            0.982    pop
# 11             0.052            0.957   rock
# 12             0.779            0.844   rock
# 13             0.844            0.953    pop
# 14             0.892            0.995    pop
# 15             0.024            0.807   rock
# 16             0.371            0.552   rock
# 17             0.165            0.880   rock
# 18             0.952            1.000   rock
# 19             0.888            0.927   rock
# 20             0.760            1.000    pop
# 21             0.833            0.947   rock
# 22             0.886            1.000   rock
# 23             0.775            1.000   rock
# 24             0.241            0.868   rock
# 25             0.318            0.552   rock
# 26             0.082            1.000   rock
# 27             0.709            1.000   rock
# 28             0.768            1.000   rock
# 29             0.768            0.920   rock
# ...              ...              ...    ...
# 2659           0.277            0.987    pop
# 2660           0.231            0.985    pop
# 2661           0.623            1.000    pop
# 2662           0.795            1.000    pop
# 2663           0.802            0.749    pop
# 2664           0.980            0.516    pop
# 2665           0.395            1.000    pop
# 2666           0.577            0.734    pop
# 2667           0.499            1.000    pop
# 2668           0.854            0.995    pop
# 2669           0.020            0.777    pop
# 2670           0.347            0.945    pop
# 2671           0.887            1.000    pop
# 2672           0.484            0.986    pop
# 2673           0.267            0.978    pop
# 2674           0.802            0.820    pop
# 2675           0.174            0.889    pop
# 2676           0.362            1.000    pop
# 2677           0.619            1.000    pop
# 2678           0.844            0.953    pop
# 2679           0.660            0.992    pop
# 2680           0.841            0.957    pop
# 2681           0.857            0.829    pop
# 2682           0.619            0.940    pop
# 2683           0.554            1.000    pop
# 2684           0.187            1.000    pop
# 2685           0.881            1.000    pop
# 2686           0.501            0.302    pop
# 2687           0.431            1.000    pop
# 2688           0.486            0.886    pop
#
# [2689 rows x 18 columns]

# %%
balanced_audioFeatures = balanced_audioFeatures_genres.drop('genres', axis = 1).copy()
scaled_balanced_audioFeatures = StandardScaler().fit_transform(balanced_audioFeatures)

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_balanced_audioFeatures, balanced_audioFeatures_genres['genres'], 
                                                   shuffle = True, test_size = 0.3, random_state = 123)

# %%
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)
predictions
# Out:
# array(['pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'rock', 'pop', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'pop', 'rock', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'pop', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'pop', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock',
#        'pop', 'pop', 'pop', 'pop', 'rock', 'pop', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock',
#        'pop', 'pop', 'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock',
#        'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'pop', 'pop', 'pop', 'rock', 'pop', 'rock', 'rock', 'pop',
#        'pop', 'pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'pop', 'pop',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock', 'pop', 'pop',
#        'pop', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'pop', 'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'rock',
#        'pop', 'rock', 'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'rock',
#        'pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'pop', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'pop', 'pop', 'pop', 'rock', 'pop', 'pop', 'rock',
#        'pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop',
#        'pop', 'pop', 'rock', 'pop', 'pop', 'rock', 'pop', 'pop', 'rock',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'pop', 'rock',
#        'pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'pop', 'rock',
#        'pop', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock', 'pop', 'rock',
#        'rock', 'pop', 'pop', 'rock', 'pop', 'pop', 'rock', 'pop', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop', 'pop', 'pop',
#        'pop', 'rock', 'pop', 'pop', 'rock', 'pop', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'pop', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'pop', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'pop', 'rock', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'rock', 'rock', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock', 'pop',
#        'rock', 'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'pop', 'rock',
#        'pop', 'pop', 'rock', 'rock', 'pop', 'rock', 'pop', 'rock', 'rock',
#        'pop', 'pop', 'pop', 'rock', 'rock', 'pop', 'pop', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock',
#        'pop', 'rock', 'pop', 'rock', 'pop', 'pop', 'rock', 'rock', 'pop',
#        'rock', 'pop', 'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock', 'rock',
#        'rock', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'pop', 'pop',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'pop', 'rock', 'pop', 'rock',
#        'rock', 'rock', 'rock', 'rock', 'pop', 'rock', 'rock', 'rock',
#        'rock', 'rock', 'pop', 'rock', 'rock', 'pop', 'pop', 'pop', 'rock',
#        'rock', 'pop', 'pop', 'rock'], dtype=object)

# %%
confus_mat = ConfusionMatrix(list(y_test), list(predictions))
classifi_report = classification_report(y_test, predictions)

print(confus_mat)
print('\n\n')
print(classifi_report)
# Out:
#      |       r |
#      |   p   o |
#      |   o   c |
#      |   p   k |
# -----+---------+
#  pop |<158> 88 |
# rock | 118<443>|
# -----+---------+
# (row = reference; col = test)
#
#
#
#
#              precision    recall  f1-score   support
#
#         pop       0.57      0.64      0.61       246
#        rock       0.83      0.79      0.81       561
#
# avg / total       0.75      0.74      0.75       807

# %%
scores = cross_validate(knn, scaled_balanced_audioFeatures, balanced_audioFeatures_genres['genres'], 
                        scoring = custom_scorer, cv = 10, return_train_score=False)
scores
# Out:
# {'fit_time': array([ 0.01129746,  0.0095427 ,  0.00946999,  0.00948977,  0.01069617,
#          0.01208639,  0.01128101,  0.00928378,  0.00936675,  0.0135107 ]),
#  'score_time': array([ 0.12429142,  0.11635685,  0.11528111,  0.11911702,  0.12508249,
#          0.1245451 ,  0.12433958,  0.11553764,  0.1147902 ,  0.11073375]),
#  'test_accuracy': array([ 0.78148148,  0.80669145,  0.73605948,  0.71747212,  0.7732342 ,
#          0.72118959,  0.71375465,  0.75092937,  0.73880597,  0.80223881]),
#  'test_precision': array([ 0.78148148,  0.80669145,  0.73605948,  0.71747212,  0.7732342 ,
#          0.72118959,  0.71375465,  0.75092937,  0.73880597,  0.80223881]),
#  'test_recall': array([ 0.78148148,  0.80669145,  0.73605948,  0.71747212,  0.7732342 ,
#          0.72118959,  0.71375465,  0.75092937,  0.73880597,  0.80223881])}

# %%
print(np.mean(scores['test_accuracy']))
print(np.mean(scores['test_precision']))
print(np.mean(scores['test_recall']))
# Out:
# 0.754185711262
# 0.754185711262
# 0.754185711262

# %% [markdown]
# ### Big dataset of rock and pop songs (6435 rock songs & 1889 pop songs), NAs are replaced by mean of same genre

# %%
audioFeatures = audioFeatureFrame(rock_pop_dataset.loc[:, 'audio_features'], audioFeatures_names)
audioFeatures.head()
# Out:
#     key    energy  liveliness    tempo  speechiness  acousticness  \
# 0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2   7.0  0.585564    0.108297  120.014     0.038924      0.011707
# 3   4.0  0.814030    0.079196  124.991     0.072440      0.005355
# 4   8.0  0.869554    0.107945  124.065     0.051083      0.132712
#
#    instrumentalness  time_signature  duration   loudness  valence  \
# 0          0.000001             0.0       4.0  218.30667   -3.890
# 1          0.012727             1.0       4.0  235.06086   -7.687
# 2          0.000005             1.0       4.0  193.57333   -6.583
# 3          0.000000             1.0       4.0  198.25333   -1.985
# 4          0.000000             1.0       4.0  227.97333   -3.739
#
#    danceability      mode  time_signature_confidence  tempo_confidence  \
# 0      0.752186  0.726920                      0.552             0.541
# 1      0.351282  0.691817                      0.737             0.634
# 2      0.622176  0.781822                      0.970             0.861
# 3      0.838512  0.700860                      0.429             0.375
# 4      0.639499  0.636239                      0.239             0.416
#
#    key_confidence  mode_confidence
# 0           1.000              1.0
# 1           0.796              1.0
# 2           0.792              1.0
# 3           0.740              1.0
# 4           0.669              1.0

# %%
audioFeatures_genres = pd.concat([audioFeatures, rock_pop_dataset.loc[:,'genres']], axis = 1)

# %%
rock_means = audioFeatures_genres[audioFeatures_genres['genres']=='rock'].drop('genres', axis = 1).mean(axis = 0, skipna = True)
pop_means = audioFeatures_genres[audioFeatures_genres['genres']=='pop'].drop('genres', axis = 1).mean(axis = 0, skipna = True)
print(rock_means)
print(pop_means)
# Out:
# key                            5.210346
# energy                         0.734346
# liveliness                     0.237767
# tempo                        125.815955
# speechiness                    0.068302
# acousticness                   0.183445
# instrumentalness               0.195228
# time_signature                 0.731086
# duration                       3.915178
# loudness                     241.738532
# valence                       -8.342550
# danceability                   0.505146
# mode                           0.456024
# time_signature_confidence      0.511554
# tempo_confidence               0.502197
# key_confidence                 0.465743
# mode_confidence                0.875100
# dtype: float64
# key                            5.065312
# energy                         0.678972
# liveliness                     0.204267
# tempo                        119.359716
# speechiness                    0.071590
# acousticness                   0.211608
# instrumentalness               0.027756
# time_signature                 0.716981
# duration                       3.973875
# loudness                     234.126035
# valence                       -7.453633
# danceability                   0.584708
# mode                           0.628267
# time_signature_confidence      0.501251
# tempo_confidence               0.520515
# key_confidence                 0.553874
# mode_confidence                0.933862
# dtype: float64
